# %% [markdown]
# # Modeling and Simulation in Python
#
# Chapter 10
#
# Copyright 2017 Allen Downey
#
# License: [Creative Commons Attribution 4.0 International](https://creativecommons.org/licenses/by/4.0)

# %%
# Configure Jupyter so figures appear in the notebook
# %matplotlib inline

# Configure Jupyter to display the assigned value after an assignment
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'

# import functions from the modsim.py module
from modsim import *

from pandas import read_html

# %% [markdown]
# ### Under the hood
#
# To get a `DataFrame` and a `Series`, I'll read the world population data and select a column.
#
# `DataFrame` and `Series` contain a variable called `shape` that indicates the number of rows and columns.

# %%
filename = 'data/World_population_estimates.html'
tables = read_html(filename, header=0, index_col=0, decimal='M')
table2 = tables[2]
table2.columns = ['census', 'prb', 'un', 'maddison', 
                  'hyde', 'tanton', 'biraben', 'mj', 
                  'thomlinson', 'durand', 'clark']
table2.shape
# Out:
# (67, 11)

# %%
census = table2.census / 1e9
census.shape
# Out:
# (67,)

# %%
un = table2.un / 1e9
un.shape
# Out:
# (67,)

# %% [markdown]
# A `DataFrame` contains `index`, which labels the rows.  It is an `Int64Index`, which is similar to a NumPy array.

# %%
table2.index
# Out:
# Int64Index([1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960,
#             1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#             1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#             1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#             1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#             2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#             2016],
#            dtype='int64', name='Year')

# %% [markdown]
# And `columns`, which labels the columns.

# %%
table2.columns
# Out:
# Index(['census', 'prb', 'un', 'maddison', 'hyde', 'tanton', 'biraben', 'mj',
#        'thomlinson', 'durand', 'clark'],
#       dtype='object')

# %% [markdown]
# And `values`, which is an array of values.

# %%
table2.values
# Out:
# array([[2557628654, 2516000000.0, 2525149000.0, 2544000000.0,
#         2527960000.0, 2400000000.0, 2527000000.0, 2500000000.0,
#         2400000000.0, nan, 2486000000.0],
#        [2594939877, nan, 2572850917.0, 2571663000.0, nan, nan, nan, nan,
#         nan, nan, nan],
#        [2636772306, nan, 2619292068.0, 2617949000.0, nan, nan, nan, nan,
#         nan, nan, nan],
#        [2682053389, nan, 2665865392.0, 2665959000.0, nan, nan, nan, nan,
#         nan, nan, nan],
#        [2730228104, nan, 2713172027.0, 2716927000.0, nan, nan, nan, nan,
#         nan, nan, nan],
#        [2782098943, nan, 2761650981.0, 2769074000.0, nan, nan, nan, nan,
#         nan, nan, nan],
#        [2835299673, nan, 2811572031.0, 2822502000.0, nan, nan, nan, nan,
#         nan, nan, nan],
#        [2891349717, nan, 2863042795.0, 2879934000.0, nan, nan, nan, nan,
#         nan, nan, nan],
#        [2948137248, nan, 2916030167.0, 2939254000.0, nan, nan, nan, nan,
#         nan, nan, nan],
# ...

# %% [markdown]
# A `Series` does not have `columns`, but it does have `name`.

# %%
census.name
# Out:
# 'census'

# %% [markdown]
# It contains `values`, which is an array.

# %%
census.values
# Out:
# array([2.55762865, 2.59493988, 2.63677231, 2.68205339, 2.7302281 ,
#        2.78209894, 2.83529967, 2.89134972, 2.94813725, 3.00071659,
#        3.04300151, 3.08396693, 3.14009322, 3.20982788, 3.28120131,
#        3.35042579, 3.42067792, 3.49033371, 3.56231382, 3.63715905,
#        3.71269774, 3.79032695, 3.86656865, 3.94209644, 4.01660881,
#        4.08908323, 4.16018501, 4.23208458, 4.30410575, 4.37901394,
#        4.45136274, 4.53441012, 4.61456656, 4.69573674, 4.77456939,
#        4.8564627 , 4.94057123, 5.02720049, 5.11455717, 5.20144011,
#        5.28895593, 5.37158592, 5.45613628, 5.53826832, 5.61868213,
#        5.69920299, 5.77944059, 5.85797254, 5.93521325, 6.01207492,
#        6.08857138, 6.16521925, 6.24201635, 6.31859096, 6.39569951,
#        6.47304473, 6.55126353, 6.62991376, 6.70904978, 6.78821439,
#        6.85858475, 6.93599949, 7.01387131, 7.09212809, 7.16996819,
#        7.24789279, 7.32599671])

# %% [markdown]
# And it contains `index`:

# %%
census.index
# Out:
# Int64Index([1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960,
#             1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#             1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#             1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#             1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#             2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#             2016],
#            dtype='int64', name='Year')

# %% [markdown]
# If you ever wonder what kind of object a variable refers to, you can use the `type` function.  The result indicates what type the object is, and the module where that type is defined.
#
# `DataFrame`, `Int64Index`, `Index`, and `Series` are defined by Pandas.
#
# `ndarray` is defined by NumPy.

# %%
type(table2)
# Out:
# pandas.core.frame.DataFrame

# %%
type(table2.index)
# Out:
# pandas.core.indexes.numeric.Int64Index

# %%
type(table2.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
type(table2.values)
# Out:
# numpy.ndarray

# %%
type(census)
# Out:
# pandas.core.series.Series

# %%
type(census.index)
# Out:
# pandas.core.indexes.numeric.Int64Index

# %%
type(census.values)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Optional exercise
#
# The following exercise provides a chance to practice what you have learned so far, and maybe develop a different growth model.  If you feel comfortable with what we have done so far, you might want to give it a try.
#
# **Optional Exercise:** On the Wikipedia page about world population estimates, the first table contains estimates for prehistoric populations.  The following cells process this table and plot some of the results.

# %%
filename = 'data/World_population_estimates.html'
tables = read_html(filename, header=0, index_col=0, decimal='M')
len(tables)
# Out:
# 6

# %% [markdown]
# Select `tables[1]`, which is the second table on the page.

# %%
table1 = tables[1]
table1.head()
# Out:
#         PRB  UN  Maddison  HYDE  Tanton  Biraben  McEvedy & Jones  Thomlinson  \
# Year
# -10000  NaN NaN       NaN   NaN     NaN      NaN              4.0         NaN
# -9000   NaN NaN       NaN   4.0     NaN      NaN              NaN         NaN
# -8000   5.0 NaN       NaN   5.0     NaN      NaN              NaN         NaN
# -7000   NaN NaN       NaN   8.0     NaN      NaN              NaN         NaN
# -6000   NaN NaN       NaN  11.0     NaN      NaN              NaN         NaN
#
#         Durand  Clark  salary_mean
# Year
# -10000     NaN    NaN          4.0
# -9000      NaN    NaN          4.0
# -8000      NaN    NaN          5.0
# -7000      NaN    NaN          8.0
# -6000      NaN    NaN         11.0

# %% [markdown]
# Not all agencies and researchers provided estimates for the same dates.  Again `NaN` is the special value that indicates missing data.

# %%
table1.tail()
# Out:
#      Population Reference Bureau (1973–2016)[15]  \
# Year
# 1913                                         NaN
# 1920                                         NaN
# 1925                                         NaN
# 1930                                         NaN
# 1940                                         NaN
#
#       United Nations Department of Economic and Social Affairs (2015)[16]  \
# Year
# 1913                                                NaN
# 1920                                             1860.0
# 1925                                                NaN
# 1930                                             2070.0
# 1940                                             2300.0
#
#      Maddison (2008)[17] HYDE (2010)[citation needed]  Tanton (1994)[18]  \
# Year
# 1913               1793.                          NaN                NaN
# 1920               1863.                        1912.                NaN
# ...

# %% [markdown]
# Again, we'll replace the long column names with more convenient abbreviations.

# %%
table1.columns = ['PRB', 'UN', 'Maddison', 'HYDE', 'Tanton', 
                  'Biraben', 'McEvedy & Jones', 'Thomlinson', 'Durand', 'Clark']

# %% [markdown]
# Some of the estimates are in a form Pandas doesn't recognize as numbers, but we can coerce them to be numeric.

# %%
for col in table1.columns:
    table1[col] = pd.to_numeric(table1[col], errors='coerce')

# %% [markdown]
# Here are the results.  Notice that we are working in millions now, not billions.

# %%
table1.plot()
decorate(xlim=[-10000, 2000], xlabel='Year', 
         ylabel='World population (millions)',
         title='Prehistoric population estimates')
plt.legend(fontsize='small');

# %% [markdown]
# We can use `xlim` to zoom in on everything after Year 0.

# %%
table1.plot()
decorate(xlim=[0, 2000], xlabel='Year', 
         ylabel='World population (millions)',
         title='CE population estimates')
plt.legend(fontsize='small');

# %% [markdown]
# See if you can find a model that fits these data well from Year 0 to 1950.
#
# How well does your best model predict actual population growth from 1950 to the present?

# %%
col = table1.loc[: , "PRB":"Clark"]
# Out:
#            PRB      UN  Maddison    HYDE  Tanton  Biraben  McEvedy & Jones  \
# Year
# -10000     NaN     NaN       NaN     NaN     NaN      NaN              4.0
# -9000      NaN     NaN       NaN     4.0     NaN      NaN              NaN
# -8000      5.0     NaN       NaN     5.0     NaN      NaN              NaN
# -7000      NaN     NaN       NaN     8.0     NaN      NaN              NaN
# -6000      NaN     NaN       NaN    11.0     NaN      NaN              NaN
# -5000      NaN     NaN       NaN     NaN     NaN      NaN              5.0
# -4000      NaN     NaN       NaN    28.0     NaN      NaN              7.0
# -3000      NaN     NaN       NaN    45.0     NaN      NaN             14.0
# -2000      NaN     NaN       NaN    72.0     NaN      NaN             27.0
# -1000      NaN     NaN       NaN   115.0     NaN      NaN             50.0
# -200       NaN     NaN       NaN     NaN     NaN      NaN            150.0
# ...

# %%
table1['population_mean'] = col.mean(axis=1)
table1
# Out:
#            PRB      UN  Maddison    HYDE  Tanton  Biraben  McEvedy & Jones  \
# Year
# -10000     NaN     NaN       NaN     NaN     NaN      NaN              4.0
# -9000      NaN     NaN       NaN     4.0     NaN      NaN              NaN
# -8000      5.0     NaN       NaN     5.0     NaN      NaN              NaN
# -7000      NaN     NaN       NaN     8.0     NaN      NaN              NaN
# -6000      NaN     NaN       NaN    11.0     NaN      NaN              NaN
# -5000      NaN     NaN       NaN     NaN     NaN      NaN              5.0
# -4000      NaN     NaN       NaN    28.0     NaN      NaN              7.0
# -3000      NaN     NaN       NaN    45.0     NaN      NaN             14.0
# -2000      NaN     NaN       NaN    72.0     NaN      NaN             27.0
# -1000      NaN     NaN       NaN   115.0     NaN      NaN             50.0
# -200       NaN     NaN       NaN     NaN     NaN      NaN            150.0
# ...

# %%
table1.population_mean
# Out:
# Year
# -10000       4.000000
# -9000        4.000000
# -8000        5.000000
# -7000        8.000000
# -6000       11.000000
# -5000        5.000000
# -4000       17.500000
# -3000       29.500000
# -2000       49.500000
# -1000       82.500000
# -200       150.000000
#  1         215.000000
#  100       195.000000
#  200       216.000000
#  300       205.000000
#  350       254.000000
#  400       201.666667
#  500       198.000000
#  600       214.000000
#  700       214.333333
#  800       236.250000
#  900       245.000000
#  1000      275.200000
#  1100      324.666667
#  1200      384.250000
#  1250      408.000000
#  1300      376.800000
#  1340      410.500000
#  1400      371.333333
#  1500      450.000000
#  1600      544.500000
#  1650      520.333333
#  1700      622.166667
#  1750      754.333333
#  1800      931.714286
#  1820     1042.000000
#  1850     1238.500000
#  1870     1276.000000
#  1875     1325.000000
#  1900     1624.375000
#  1910     1763.500000
# ...

# %%
from scipy.interpolate import *
from numpy import *

# %%
p1 = polyfit(table1.index,table1.population_mean,1)
# Out:
# array([1.14019266e-01, 6.25097828e+02])

# %%
from matplotlib import *

# %%
# %matplotlib inline

# %%
plot(table1.index,table1.population_mean,'o')
plot(table1.index,polyval(p1,table1.index),'r-')

# %% [markdown]
# clearly this is not a good fit

# %%
p2 = polyfit(table1.index,table1.population_mean,2)
plot(table1.index,table1.population_mean,'o')
plot(table1.index,polyval(p2,table1.index),'r-')

# %%
p3 = polyfit(table1.index,table1.population_mean,3)
plot(table1.index,table1.population_mean,'o')
plot(table1.index,polyval(p3,table1.index),'r-')

# %% [markdown]
# I tried multiple ways to create a logistic model that I could fit this to but did not succeed:

# %%
from scipy.optimize import curve_fit
from scipy.special import expit

# %%
xdata=table1.index.values,
ydata=table1.population_mean.values
# Out:
# array([   4.        ,    4.        ,    5.        ,    8.        ,
#          11.        ,    5.        ,   17.5       ,   29.5       ,
#          49.5       ,   82.5       ,  150.        ,  215.        ,
#         195.        ,  216.        ,  205.        ,  254.        ,
#         201.66666667,  198.        ,  214.        ,  214.33333333,
#         236.25      ,  245.        ,  275.2       ,  324.66666667,
#         384.25      ,  408.        ,  376.8       ,  410.5       ,
#         371.33333333,  450.        ,  544.5       ,  520.33333333,
#         622.16666667,  754.33333333,  931.71428571, 1042.        ,
#        1238.5       , 1276.        , 1325.        , 1624.375     ,
#        1763.5       , 1793.        , 1900.75      , 2000.        ,
#        2102.33333333, 2311.5       ])

# %%
xdata
# Out:
# (array([-10000,  -9000,  -8000,  -7000,  -6000,  -5000,  -4000,  -3000,
#          -2000,  -1000,   -200,      1,    100,    200,    300,    350,
#            400,    500,    600,    700,    800,    900,   1000,   1100,
#           1200,   1250,   1300,   1340,   1400,   1500,   1600,   1650,
#           1700,   1750,   1800,   1820,   1850,   1870,   1875,   1900,
#           1910,   1913,   1920,   1925,   1930,   1940], dtype=int64),)

# %%
ydata
# Out:
# array([   4.        ,    4.        ,    5.        ,    8.        ,
#          11.        ,    5.        ,   17.5       ,   29.5       ,
#          49.5       ,   82.5       ,  150.        ,  215.        ,
#         195.        ,  216.        ,  205.        ,  254.        ,
#         201.66666667,  198.        ,  214.        ,  214.33333333,
#         236.25      ,  245.        ,  275.2       ,  324.66666667,
#         384.25      ,  408.        ,  376.8       ,  410.5       ,
#         371.33333333,  450.        ,  544.5       ,  520.33333333,
#         622.16666667,  754.33333333,  931.71428571, 1042.        ,
#        1238.5       , 1276.        , 1325.        , 1624.375     ,
#        1763.5       , 1793.        , 1900.75      , 2000.        ,
#        2102.33333333, 2311.5       ])

# %%
def sigmoid(x, L ,x0, k, b):
    y = L / (1 + expit(-k*(x-x0)))+b
    return (y)

p0 = [max(ydata), np.median(xdata),1,min(ydata)] # this is an mandatory initial guess
# Out:
# [2311.5, 1050.0, 1, 4.0]

# %%
popt, pcov = curve_fit(sigmoid, xdata, ydata,p0, method='dogbox')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-ee95a9b95de7> in <module>
# ----> 1 popt, pcov = curve_fit(sigmoid, xdata, ydata,p0, method='dogbox')
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     773
#     774         res = least_squares(func, p0, jac=jac, bounds=bounds, method=method,
# --> 775                             **kwargs)
#     776
#     777         if not res.success:
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     809     if f0.ndim != 1:
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# %%
x=table1.index,
y=table1.population_mean
# Out:
# Year
# -10000       4.000000
# -9000        4.000000
# -8000        5.000000
# -7000        8.000000
# -6000       11.000000
# -5000        5.000000
# -4000       17.500000
# -3000       29.500000
# -2000       49.500000
# -1000       82.500000
# -200       150.000000
#  1         215.000000
#  100       195.000000
#  200       216.000000
#  300       205.000000
#  350       254.000000
#  400       201.666667
#  500       198.000000
#  600       214.000000
#  700       214.333333
#  800       236.250000
#  900       245.000000
#  1000      275.200000
#  1100      324.666667
#  1200      384.250000
#  1250      408.000000
#  1300      376.800000
#  1340      410.500000
#  1400      371.333333
#  1500      450.000000
#  1600      544.500000
#  1650      520.333333
#  1700      622.166667
#  1750      754.333333
#  1800      931.714286
#  1820     1042.000000
#  1850     1238.500000
#  1870     1276.000000
#  1875     1325.000000
#  1900     1624.375000
#  1910     1763.500000
# ...

# %%
model = LogisticRegression(solver='liblinear', random_state=0)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=0, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
model.fit(x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-d3dc977168f5> in <module>
# ----> 1 model.fit(x, y)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1525
#    1526         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1527                          accept_large_sparse=solver != 'liblinear')
#    1528         check_classification_targets(y)
#    1529         self.classes_ = np.unique(y)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     763         y = y.astype(np.float64)
#     764
# --> 765     check_consistent_length(X, y)
# ...

# %%
import numpy as np
import scipy.optimize as opt
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def f(x, a, b, c, d):
    return a / (1. + exp(-c * (x - d))) + b

# %%
a, c = np.random.exponential(size=2)
b, d = np.random.randn(2)

# %%
x=table1.index,
y=table1.population_mean
# Out:
# Year
# -10000       4.000000
# -9000        4.000000
# -8000        5.000000
# -7000        8.000000
# -6000       11.000000
# -5000        5.000000
# -4000       17.500000
# -3000       29.500000
# -2000       49.500000
# -1000       82.500000
# -200       150.000000
#  1         215.000000
#  100       195.000000
#  200       216.000000
#  300       205.000000
#  350       254.000000
#  400       201.666667
#  500       198.000000
#  600       214.000000
#  700       214.333333
#  800       236.250000
#  900       245.000000
#  1000      275.200000
#  1100      324.666667
#  1200      384.250000
#  1250      408.000000
#  1300      376.800000
#  1340      410.500000
#  1400      371.333333
#  1500      450.000000
#  1600      544.500000
#  1650      520.333333
#  1700      622.166667
#  1750      754.333333
#  1800      931.714286
#  1820     1042.000000
#  1850     1238.500000
#  1870     1276.000000
#  1875     1325.000000
#  1900     1624.375000
#  1910     1763.500000
# ...

# %%
(a_, b_, c_, d_), _ = opt.curve_fit(f, x, y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-0eee395fb37c> in <module>
# ----> 1 (a_, b_, c_, d_), _ = opt.curve_fit(f, x, y)
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     761         # Remove full_output from kwargs, otherwise we're passing it in twice.
#     762         return_full = kwargs.pop('full_output', False)
# --> 763         res = leastsq(func, p0, Dfun=jac, full_output=1, **kwargs)
#     764         popt, pcov, infodict, errmsg, ier = res
#     765         ysize = len(infodict['fvec'])
#
# ...

# %%
(a_, b_, c_, d_), _ = opt.curve_fit(f, x, y)

# %%
y_fit = f(x, a_, b_, c_, d_)

fig, ax = plt.subplots(1, 1, figsize=(6, 4))
ax.plot(x, y_model, '--k')
ax.plot(x, y, 'o')
ax.plot(x, y_fit, '-')
